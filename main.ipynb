# %%
import requests
import json

# 'X-Goog-FieldMask': 'places.displayName,places.formattedAddress,places.priceLevel'
# 'X-Goog-FieldMask': 'places.displayName,places.rating,places.formattedAddress,places.types,places.viewport'

def textsearchrequest():
    # should remove key when publishing to github
    myapikey = ''
    url = 'https://places.googleapis.com/v1/places:searchText'

    headers = {
        'Content-Type': 'application/json',
        'X-Goog-Api-Key': myapikey,
        'X-Goog-FieldMask': '*'
    }
    data = {
        'textQuery': 'whole foods',
        'maxResultCount': 5,
        'locationBias': {
            'circle': {
                'center': {
                    'latitude': 40.764917,
                    'longitude': -73.9897431
                },
                'radius': 1000.0   
                }
            }
    }
    # want to create a function that can create a locationbias based on a latitude and longitude created from a search of a location (ex. Upper East Side 72d st)
    # input the long and lat values into the data var here before calling the request

    
    response = requests.post(url, json=data, headers=headers)
    data = json.loads(response.text)
    print(data)
    return data

test = textsearchrequest()
# Out:
# {'places': [{'name': 'places/ChIJvaMqIvZYwokR9tb1ok27g8U', 'id': 'ChIJvaMqIvZYwokR9tb1ok27g8U', 'types': ['grocery_store', 'liquor_store', 'supermarket', 'market', 'store', 'health', 'food', 'point_of_interest', 'establishment'], 'nationalPhoneNumber': '(212) 823-9600', 'internationalPhoneNumber': '+1 212-823-9600', 'formattedAddress': '10 Columbus Cir Ste Sc101, New York, NY 10019, USA', 'addressComponents': [{'longText': 'Ste Sc101', 'shortText': 'Ste Sc101', 'types': ['subpremise'], 'languageCode': 'en'}, {'longText': '10', 'shortText': '10', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'Columbus Circle', 'shortText': 'Columbus Cir', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Manhattan', 'shortText': 'Manhattan', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'New York', 'types': ['locality', 'political'], 'languageCode': 'en'}, {'longText': 'New York County', 'shortText': 'New York County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '10019', 'shortText': '10019', 'types': ['postal_code'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8Q298+CP', 'compoundCode': 'Q298+CP New York, NY, USA'}, 'location': {'latitude': 40.7685526, 'longitude': -73.9831866}, 'viewport': {'low': {'latitude': 40.767041519708506, 'longitude': -73.98428528029152}, 'high': {'latitude': 40.769739480291506, 'longitude': -73.9815873197085}}, 'rating': 4.3, 'googleMapsUri': 'https://maps.google.com/?cid=14232425189541795574', 'websiteUri': 'https://www.wholefoodsmarket.com/stores/columbuscircle?utm_source=google&utm_medium=organic&utm_campaign=listings', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0}, 'close': {'day': 0, 'hour': 22, 'minute': 0}}, {'open': {'day': 1, 'hour': 7, 'minute': 0}, 'close': {'day': 1, 'hour': 22, 'minute': 0}}, {'open': {'day': 2, 'hour': 7, 'minute': 0}, 'close': {'day': 2, 'hour': 22, 'minute': 0}}, {'open': {'day': 3, 'hour': 7, 'minute': 0}, 'close': {'day': 3, 'hour': 22, 'minute': 0}}, {'open': {'day': 4, 'hour': 7, 'minute': 0}, 'close': {'day': 4, 'hour': 22, 'minute': 0}}, {'open': {'day': 5, 'hour': 7, 'minute': 0}, 'close': {'day': 5, 'hour': 22, 'minute': 0}}, {'open': {'day': 6, 'hour': 7, 'minute': 0}, 'close': {'day': 6, 'hour': 22, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u200910:00\u202fPM', 'Tuesday: 7:00\u202fAM\u2009–\u200910:00\u202fPM', 'Wednesday: 7:00\u202fAM\u2009–\u200910:00\u202fPM', 'Thursday: 7:00\u202fAM\u2009–\u200910:00\u202fPM', 'Friday: 7:00\u202fAM\u2009–\u200910:00\u202fPM', 'Saturday: 7:00\u202fAM\u2009–\u200910:00\u202fPM', 'Sunday: 7:00\u202fAM\u2009–\u200910:00\u202fPM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">10 Columbus Cir Ste Sc101</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10019</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'priceLevel': 'PRICE_LEVEL_EXPENSIVE', 'userRatingCount': 3722, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'Whole Foods Market', 'languageCode': 'en'}, 'takeout': True, 'delivery': True, 'curbsidePickup': True, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 0, 'hour': 22, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}}, {'open': {'day': 1, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day' ...

# %%
myfirst = test['places'][0:3]
myfirst
# Out:
# [{'name': 'places/ChIJvaMqIvZYwokR9tb1ok27g8U',
#   'id': 'ChIJvaMqIvZYwokR9tb1ok27g8U',
#   'types': ['grocery_store',
#    'liquor_store',
#    'supermarket',
#    'market',
#    'store',
#    'health',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'nationalPhoneNumber': '(212) 823-9600',
#   'internationalPhoneNumber': '+1 212-823-9600',
#   'formattedAddress': '10 Columbus Cir Ste Sc101, New York, NY 10019, USA',
#   'addressComponents': [{'longText': 'Ste Sc101',
#     'shortText': 'Ste Sc101',
#     'types': ['subpremise'],
#     'languageCode': 'en'},
#    {'longText': '10',
#     'shortText': '10',
#     'types': ['street_number'],
#     'languageCode': 'en-US'},
#    {'longText': 'Columbus Circle',
#     'shortText': 'Columbus Cir',
#     'types': ['route'],
#     'languageCode': 'en'},
#    {'longText': 'Manhattan',
#     'shortText': 'Manhattan',
#     'types': ['sublocality_level_1', 'sublocality', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York',
#     'shortText': 'New York',
#     'types': ['locality', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York County',
#     'shortText': 'New York County',
#     'types': ['administrative_area_level_2', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York',
#     'shortText': 'NY',
#     'types': ['administrative_area_level_1', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'United States',
#     'shortText': 'US',
#     'types': ['country', 'political'],
#     'languageCode': 'en'},
#    {'longText': '10019',
#     'shortText': '10019',
#     'types': ['postal_code'],
#     'languageCode': 'en-US'}],
#   'plusCode': {'globalCode': '87G8Q298+CP',
#    'compoundCode': 'Q298+CP New York, NY, USA'},
#   'location': {'latitude': 40.7685526, 'longitude': -73.9831866},
#   'viewport': {'low': {'latitude': 40.767041519708506,
#     'longitude': -73.98428528029152},
#    'high': {'latitude': 40.769739480291506, 'longitude': -73.9815873197085}},
#   'rating': 4.3,
#   'googleMapsUri': 'https://maps.google.com/?cid=14232425189541795574',
#   'websiteUri': 'https://www.wholefoodsmarket.com/stores/columbuscircle?utm_source=google&utm_medium=organic&utm_campaign=listings',
#   'regularOpeningHours': {'openNow': True,
#    'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0},
#      'close': {'day': 0, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 1, 'hour': 7, 'minute': 0},
#      'close': {'day': 1, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 2, 'hour': 7, 'minute': 0},
#      'close': {'day': 2, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 3, 'hour': 7, 'minute': 0},
#      'close': {'day': 3, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 4, 'hour': 7, 'minute': 0},
#      'close': {'day': 4, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 5, 'hour': 7, 'minute': 0},
#      'close': {'day': 5, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 6, 'hour': 7, 'minute': 0},
#      'close': {'day': 6, 'hour': 22, 'minute': 0}}],
#    'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Tuesday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Wednesday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Thursday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Friday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Saturday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Sunday: 7:00\u202fAM\u2009–\u200910:00\u202fPM']},
#   'utcOffsetMinutes': -240,
#   'adrFormatAddress': '<span class="street-address">10 Columbus Cir Ste Sc101</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10019</span>, <span class="country-name">USA</span>',
#   'businessStatus': 'OPERATIONAL',
#   'priceLevel': 'PRICE_LEVEL_EXPENSIVE',
#   'userRatingCount': 3722,
#   'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#   'iconBackgroundColor': '#4B96F3',
#   'displayName': {'text': 'Whole Foods Market', 'languageCode': 'en'},
#   'takeout': True,
#   'delivery': True,
#   'curbsidePickup': True,
#   'currentOpeningHours': {'openNow': True,
#    'periods': [{'open': {'day': 0,
#       'hour': 7,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 15}},
#      'close': {'day': 0,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 15}}},
#     {'open': {'day': 1,
#       'hour': 7,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 16}},
#      'close': {'day': 1,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 16}}},
#     {'open': {'day': 2,
#       'hour': 7,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 17}},
#      'close': {'day': 2,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 17}}},
#     {'open': {'day': 3,
#       'hour': 7,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 18}},
#      'close': {'day': 3,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 18}}},
#     {'open': {'day': 4,
#       'hour': 7,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 12}},
#      'close': {'day': 4,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 12}}},
#     {'open': {'day': 5,
#       'hour': 7,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 13}},
#      'close': {'day': 5,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 13}}},
#     {'open': {'day': 6,
#       'hour': 7,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 14}},
#      'close': {'day': 6,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 14}}}],
#    'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Tuesday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Wednesday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Thursday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Friday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Saturday: 7:00\u202fAM\u2009–\u200910:00\u202fPM',
#     'Sunday: 7:00\u202fAM\u2009–\u200910:00\u202fPM']},
#   'editorialSummary': {'text': 'Eco-minded chain with natural & organic grocery items, housewares & other products (most sell wine).',
#    'languageCode': 'en'},
#   'reviews': [{'relativePublishTimeDescription': 'a month ago',
#     'rating': 4,
#     'text': {'text': 'Well supplied supermarket located right in the Columbus circle. It is always overcrowded here but it is well organized. The hot bar is a good way to get some food but be careful with the portion, $14/lb. There is often quite difficult to find a place to sit but I recommend to take your food to the Central Park.',
#      'languageCode': 'en'},
#     'originalText': {'text': 'Well supplied supermarket located right in the Columbus circle. It is always overcrowded here but it is well organized. The hot bar is a good way to get some food but be careful with the portion, $14/lb. There is often quite difficult to find a place to sit but I recommend to take your food to the Central Park.',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Petr Konečný',
#      'uri': 'https://www.google.com/maps/contrib/106451568934276579039/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjW-rB-wpO16O7oM8OH-_CYUxMDXZHC1ZQ6IE8XpODVS99k=s128-c0x00000000-cc-rp-mo-ba4'},
#     'publishTime': '2023-08-15T09:27:41Z'},
#    {'relativePublishTimeDescription': '10 months ago',
#     'rating': 4,
#     'text': {'text': 'The Columbus Circle wholefoods is a bit different than others around the city. Typically very packed. However, staff from every level are very friendly and helpful. Don’t always find what I need in stock but at same time find items other locations don’t carry. The self checkout is probably one of the best checkouts out of all the stores who offer it. Making it quick to checkout and never have to wait in line despite the business of customers. Recommend',
#      'languageCode': 'en'},
#     'originalText': {'text': 'The Columbus Circle wholefoods is a bit different than others around the city. Typically very packed. However, staff from every level are very friendly and helpful. Don’t always find what I need in stock but at same time find items other locations don’t carry. The self checkout is probably one of the best checkouts out of all the stores who offer it. Making it quick to checkout and never have to wait in line despite the business of customers. Recommend',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Adam M',
#      'uri': 'https://www.google.com/maps/contrib/104094626023846271895/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjWRMkrsHKUpCUerX05ycX0Tx5Ibb7gWFaFiaXuE-YHBAZgw=s128-c0x00000000-cc-rp-mo-ba5'},
#     'publishTime': '2022-12-06T09:50:09Z'},
#    {'relativePublishTimeDescription': 'a week ago',
#     'rating': 5,
#     'text': {'text': "Great prices. Very clean. Loved that there was a restroom. Loved that there were tables to eat at. It was stocked well. It was crowded, but the store is so big. I wouldn't have noticed until I got to checkout. There were so many self checkouts availability that I decided to use. The line for checkhout with a cashier was  running just as smoothly. Many cashiers were working.",
#      'languageCode': 'en'},
#     'originalText': {'text': "Great prices. Very clean. Loved that there was a restroom. Loved that there were tables to eat at. It was stocked well. It was crowded, but the store is so big. I wouldn't have noticed until I got to checkout. There were so many self checkouts availability that I decided to use. The line for checkhout with a cashier was  running just as smoothly. Many cashiers were working.",
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Shannon Munz',
#      'uri': 'https://www.google.com/maps/contrib/113426258465773130789/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUNehTl2OKjgRuP8hoQ5j9g1m07ZUQIfnDVFMAyt1nTcQ=s128-c0x00000000-cc-rp-mo'},
#     'publishTime': '2023-09-29T19:05:10Z'},
#    {'relativePublishTimeDescription': '3 months ago',
#     'rating': 4,
#     'text': {'text': 'Right in Columbus Circle Whole Foods was super busy.  Well stocked and plenty of variety from the butcher, deli and kitchen. We took some pizza a cheese slice and buffalo slice to munch. The buffalo slice was super salty!!',
#      'languageCode': 'en'},
#     'originalText': {'text': 'Right in Columbus Circle Whole Foods was super busy.  Well stocked and plenty of variety from the butcher, deli and kitchen. We took some pizza a cheese slice and buffalo slice to munch. The buffalo slice was super salty!!',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Nini Kaur',
#      'uri': 'https://www.google.com/maps/contrib/104812748361405504702/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjVwTrCGn7XPw063DVRuSxkGFmX9QgF0qWqeH-OKvp2B42rU=s128-c0x00000000-cc-rp-mo-ba6'},
#     'publishTime': '2023-07-11T20:27:34Z'},
#    {'relativePublishTimeDescription': '2 weeks ago',
#     'rating': 5,
#     'text': {'text': "There are many Whole Foods in NYC but this branch is special. This particular market has everything you need, it's clean and well run, customers are well-dressed,  the cashiers work quickly and the staff know where everything is. The only downside is the price. But if you consider you get what you pay for, it's an elevated luxury shopping experience for gourmet, healthy groceries in an elegant mall ... so maybe it's worth the price.",
#      'languageCode': 'en'},
#     'originalText': {'text': "There are many Whole Foods in NYC but this branch is special. This particular market has everything you need, it's clean and well run, customers are well-dressed,  the cashiers work quickly and the staff know where everything is. The only downside is the price. But if you consider you get what you pay for, it's an elevated luxury shopping experience for gourmet, healthy groceries in an elegant mall ... so maybe it's worth the price.",
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Kyle McCarthy',
#      'uri': 'https://www.google.com/maps/contrib/107616455683845830905/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjWx6AisyPAkHlXwUlu_pD2YxSzruMN04ZmEsCVupNCFESTi=s128-c0x00000000-cc-rp-mo-ba5'},
#     'publishTime': '2023-09-27T00:57:24Z'}],
#   'accessibilityOptions': {'wheelchairAccessibleEntrance': True}},
#  {'name': 'places/ChIJC2AqwapZwokR2O17hSVPjrE',
#   'id': 'ChIJC2AqwapZwokR2O17hSVPjrE',
#   'types': ['grocery_store',
#    'liquor_store',
#    'supermarket',
#    'market',
#    'store',
#    'health',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'nationalPhoneNumber': '(917) 728-5700',
#   'internationalPhoneNumber': '+1 917-728-5700',
#   'formattedAddress': '1095 6th Ave, New York, NY 10036, USA',
#   'addressComponents': [{'longText': '1095',
#     'shortText': '1095',
#     'types': ['street_number'],
#     'languageCode': 'en-US'},
#    {'longText': '6th Avenue',
#     'shortText': '6th Ave',
#     'types': ['route'],
#     'languageCode': 'en'},
#    {'longText': 'Manhattan',
#     'shortText': 'Manhattan',
#     'types': ['sublocality_level_1', 'sublocality', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York',
#     'shortText': 'New York',
#     'types': ['locality', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York County',
#     'shortText': 'New York County',
#     'types': ['administrative_area_level_2', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York',
#     'shortText': 'NY',
#     'types': ['administrative_area_level_1', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'United States',
#     'shortText': 'US',
#     'types': ['country', 'political'],
#     'languageCode': 'en'},
#    {'longText': '10036',
#     'shortText': '10036',
#     'types': ['postal_code'],
#     'languageCode': 'en-US'}],
#   'plusCode': {'globalCode': '87G8Q238+R4',
#    'compoundCode': 'Q238+R4 New York, NY, USA'},
#   'location': {'latitude': 40.7545529, 'longitude': -73.984657},
#   'viewport': {'low': {'latitude': 40.7531184197085,
#     'longitude': -73.9858652302915},
#    'high': {'latitude': 40.7558163802915, 'longitude': -73.98316726970849}},
#   'rating': 4.4,
#   'googleMapsUri': 'https://maps.google.com/?cid=12794250613978033624',
#   'websiteUri': 'https://www.wholefoodsmarket.com/stores/bryantpark?utm_source=google&utm_medium=organic&utm_campaign=listings',
#   'regularOpeningHours': {'openNow': True,
#    'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 0},
#      'close': {'day': 0, 'hour': 21, 'minute': 0}},
#     {'open': {'day': 1, 'hour': 8, 'minute': 0},
#      'close': {'day': 1, 'hour': 21, 'minute': 0}},
#     {'open': {'day': 2, 'hour': 8, 'minute': 0},
#      'close': {'day': 2, 'hour': 21, 'minute': 0}},
#     {'open': {'day': 3, 'hour': 8, 'minute': 0},
#      'close': {'day': 3, 'hour': 21, 'minute': 0}},
#     {'open': {'day': 4, 'hour': 8, 'minute': 0},
#      'close': {'day': 4, 'hour': 21, 'minute': 0}},
#     {'open': {'day': 5, 'hour': 8, 'minute': 0},
#      'close': {'day': 5, 'hour': 21, 'minute': 0}},
#     {'open': {'day': 6, 'hour': 8, 'minute': 0},
#      'close': {'day': 6, 'hour': 21, 'minute': 0}}],
#    'weekdayDescriptions': ['Monday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Tuesday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Wednesday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Thursday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Friday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Saturday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Sunday: 8:00\u202fAM\u2009–\u20099:00\u202fPM']},
#   'utcOffsetMinutes': -240,
#   'adrFormatAddress': '<span class="street-address">1095 6th Ave</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10036</span>, <span class="country-name">USA</span>',
#   'businessStatus': 'OPERATIONAL',
#   'priceLevel': 'PRICE_LEVEL_EXPENSIVE',
#   'userRatingCount': 6570,
#   'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#   'iconBackgroundColor': '#4B96F3',
#   'displayName': {'text': 'Whole Foods Market', 'languageCode': 'en'},
#   'delivery': True,
#   'dineIn': False,
#   'curbsidePickup': True,
#   'currentOpeningHours': {'openNow': True,
#    'periods': [{'open': {'day': 0,
#       'hour': 8,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 15}},
#      'close': {'day': 0,
#       'hour': 21,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 15}}},
#     {'open': {'day': 1,
#       'hour': 8,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 16}},
#      'close': {'day': 1,
#       'hour': 21,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 16}}},
#     {'open': {'day': 2,
#       'hour': 8,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 17}},
#      'close': {'day': 2,
#       'hour': 21,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 17}}},
#     {'open': {'day': 3,
#       'hour': 8,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 18}},
#      'close': {'day': 3,
#       'hour': 21,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 18}}},
#     {'open': {'day': 4,
#       'hour': 8,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 12}},
#      'close': {'day': 4,
#       'hour': 21,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 12}}},
#     {'open': {'day': 5,
#       'hour': 8,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 13}},
#      'close': {'day': 5,
#       'hour': 21,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 13}}},
#     {'open': {'day': 6,
#       'hour': 8,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 14}},
#      'close': {'day': 6,
#       'hour': 21,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 14}}}],
#    'weekdayDescriptions': ['Monday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Tuesday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Wednesday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Thursday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Friday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Saturday: 8:00\u202fAM\u2009–\u20099:00\u202fPM',
#     'Sunday: 8:00\u202fAM\u2009–\u20099:00\u202fPM']},
#   'editorialSummary': {'text': 'Eco-minded chain with natural & organic grocery items, housewares & other products (most sell wine).',
#    'languageCode': 'en'},
#   'reviews': [{'relativePublishTimeDescription': '2 months ago',
#     'rating': 4,
#     'text': {'text': 'This store is about the closest thing you will get to perfection except they sometimes don\'t have what I need and they discontinue popular items when stores in other regions do not.\n\nCase-in-point:\nFirst visit, I stopped in to get some fresh squeezed orange juice. Its expensive, but its reliably organic and fresh and worth it. They only had the OJ in the large (I believe, gallon) size, which costs $17.99. None of the smaller sizes were offered.\n\nSecond visit, I wanted to grab a few individual packs of the 365 Lavendar Hand Sanitizing Wipes. I could find them the month prior but during this trip, they were nowhere in sight I go to customer service. they tell me that they were discontinued. But, wait. Every other store in every other state has them. "Some things sell in some regions and not in others, so that\'s not abnormal."\n\nYeah, annoying. Almost 3-star annoying, but its Whole foods, so.\n\nI stopped in to use their bathroom and I was a bit shocked at how unkempt it was. I have never been to a Wholefoods bathroom that was not as clean as my bathroom at home.\n\nWhen I stopped at the customer service desk about those sanitizing wipes, I overheard a conversation between employees where I guess its common for folks at this place to tell managers "that\'s not in my job description," maybe that\'s why I couldn\'t get OJ that one day and sanitizing wipes the next. Its not somebody\'s job.',
#      'languageCode': 'en'},
#     'originalText': {'text': 'This store is about the closest thing you will get to perfection except they sometimes don\'t have what I need and they discontinue popular items when stores in other regions do not.\n\nCase-in-point:\nFirst visit, I stopped in to get some fresh squeezed orange juice. Its expensive, but its reliably organic and fresh and worth it. They only had the OJ in the large (I believe, gallon) size, which costs $17.99. None of the smaller sizes were offered.\n\nSecond visit, I wanted to grab a few individual packs of the 365 Lavendar Hand Sanitizing Wipes. I could find them the month prior but during this trip, they were nowhere in sight I go to customer service. they tell me that they were discontinued. But, wait. Every other store in every other state has them. "Some things sell in some regions and not in others, so that\'s not abnormal."\n\nYeah, annoying. Almost 3-star annoying, but its Whole foods, so.\n\nI stopped in to use their bathroom and I was a bit shocked at how unkempt it was. I have never been to a Wholefoods bathroom that was not as clean as my bathroom at home.\n\nWhen I stopped at the customer service desk about those sanitizing wipes, I overheard a conversation between employees where I guess its common for folks at this place to tell managers "that\'s not in my job description," maybe that\'s why I couldn\'t get OJ that one day and sanitizing wipes the next. Its not somebody\'s job.',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'I Am Sharon',
#      'uri': 'https://www.google.com/maps/contrib/110812395655747069014/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocLCllJUNUxis1fRRcaYfw9yL-UvEae4-jdy5VQNpRJb=s128-c0x00000000-cc-rp-mo-ba5'},
#     'publishTime': '2023-08-10T14:38:58Z'},
#    {'relativePublishTimeDescription': '5 months ago',
#     'rating': 4,
#     'text': {'text': 'I came here a few weeks ago because I was in the area with some friends on a trip. I came in to get some snacks and to find a bathroom, the store as a whole is very nice and it’s very big too there’s 2 floors of just anything you can think of. I went and bought my snacks but when I went to go look for the bathroom it was kind of a hassle to find and when I did end up finding it there was a pretty decent line. Other than the bathroom thing I would definitely come back again in the future if I’m ever in the area again.',
#      'languageCode': 'en'},
#     'originalText': {'text': 'I came here a few weeks ago because I was in the area with some friends on a trip. I came in to get some snacks and to find a bathroom, the store as a whole is very nice and it’s very big too there’s 2 floors of just anything you can think of. I went and bought my snacks but when I went to go look for the bathroom it was kind of a hassle to find and when I did end up finding it there was a pretty decent line. Other than the bathroom thing I would definitely come back again in the future if I’m ever in the area again.',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Nicole Flood',
#      'uri': 'https://www.google.com/maps/contrib/105224035100317766817/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUr5-YGAa4n73OoOPXZFDf0W4EY56Q7mrqsK6JUI86Xh6g=s128-c0x00000000-cc-rp-mo-ba6'},
#     'publishTime': '2023-05-13T04:04:28Z'},
#    {'relativePublishTimeDescription': '4 months ago',
#     'rating': 4,
#     'text': {'text': "Hippest store but...they don't clean the sitting area often enough and it seems that items on sale don't hit this store as often as others...it's like Whole Foods determines they can get retail out of customers here...so why bother taking less money oer square inch? I visited another store in NJ the same week and again ( it seems, NY vs. NJ) like a lot more was on sale.\n\nOne of the nicest places to sit and look into the trees of Bryant Park (sitting area is 2nd floor).  It is best to listen to relaxing music as you watch the world go by when you are doing it.  It's definitely worth a visit!",
#      'languageCode': 'en'},
#     'originalText': {'text': "Hippest store but...they don't clean the sitting area often enough and it seems that items on sale don't hit this store as often as others...it's like Whole Foods determines they can get retail out of customers here...so why bother taking less money oer square inch? I visited another store in NJ the same week and again ( it seems, NY vs. NJ) like a lot more was on sale.\n\nOne of the nicest places to sit and look into the trees of Bryant Park (sitting area is 2nd floor).  It is best to listen to relaxing music as you watch the world go by when you are doing it.  It's definitely worth a visit!",
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'MikSchlag',
#      'uri': 'https://www.google.com/maps/contrib/106564752965279647711/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUpe6Jlzzx-b2HDkm3I0o2K3B-BU7ayhyUtVRFbEi1KuKI=s128-c0x00000000-cc-rp-mo-ba5'},
#     'publishTime': '2023-05-28T12:47:55Z'},
#    {'relativePublishTimeDescription': '7 months ago',
#     'rating': 5,
#     'text': {'text': "I recently visited the Whole Foods on 41st Street and 6th Ave and was really impressed with the store's selection and quality of products. The staff were friendly and helpful, and the store was clean and well-organized. I especially enjoyed the wide variety of fresh produce and the large bulk foods section. The prices were a bit higher than other grocery stores, but I felt that the quality of the products justified the cost. Additionally, I was pleasantly surprised by the buffet, which had a wide variety of selections and looked incredibly fresh and appetizing. Overall, I would definitely recommend this Whole Foods location to anyone looking for high-quality, organic groceries in the area.",
#      'languageCode': 'en'},
#     'originalText': {'text': "I recently visited the Whole Foods on 41st Street and 6th Ave and was really impressed with the store's selection and quality of products. The staff were friendly and helpful, and the store was clean and well-organized. I especially enjoyed the wide variety of fresh produce and the large bulk foods section. The prices were a bit higher than other grocery stores, but I felt that the quality of the products justified the cost. Additionally, I was pleasantly surprised by the buffet, which had a wide variety of selections and looked incredibly fresh and appetizing. Overall, I would definitely recommend this Whole Foods location to anyone looking for high-quality, organic groceries in the area.",
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Tomasz Lodowski',
#      'uri': 'https://www.google.com/maps/contrib/102405945348747746297/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjX8Wrexy_moMONhEZsWoz6RB3OEzrB5OtaIHSDdRmsk1iQ=s128-c0x00000000-cc-rp-mo-ba6'},
#     'publishTime': '2023-03-11T03:30:10Z'},
#    {'relativePublishTimeDescription': '6 months ago',
#     'rating': 5,
#     'text': {'text': 'Bryant Square WFM is a great place to go to the salad and hot bar for good food at a good value. $13.95 for a pound is up there in price but a good value for healthy food.',
#      'languageCode': 'en'},
#     'originalText': {'text': 'Bryant Square WFM is a great place to go to the salad and hot bar for good food at a good value. $13.95 for a pound is up there in price but a good value for healthy food.',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Mark McHugh',
#      'uri': 'https://www.google.com/maps/contrib/108344066062649263367/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjVX_jFC-mXc3n6EU_IA-x1JBOSwfqxJa4b7MvWtc8EPcQ=s128-c0x00000000-cc-rp-mo-ba6'},
#     'publishTime': '2023-04-13T17:36:31Z'}],
#   'accessibilityOptions': {'wheelchairAccessibleEntrance': True}},
#  {'name': 'places/ChIJI2yhZBxZwokRaLg_A-8sqDA',
#   'id': 'ChIJI2yhZBxZwokRaLg_A-8sqDA',
#   'types': ['grocery_store',
#    'liquor_store',
#    'supermarket',
#    'market',
#    'store',
#    'health',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'nationalPhoneNumber': '(646) 540-1104',
#   'internationalPhoneNumber': '+1 646-540-1104',
#   'formattedAddress': '450 W 33rd St, New York, NY 10001, USA',
#   'addressComponents': [{'longText': '450',
#     'shortText': '450',
#     'types': ['street_number'],
#     'languageCode': 'en-US'},
#    {'longText': 'West 33rd Street',
#     'shortText': 'W 33rd St',
#     'types': ['route'],
#     'languageCode': 'en'},
#    {'longText': 'Manhattan',
#     'shortText': 'Manhattan',
#     'types': ['sublocality_level_1', 'sublocality', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York',
#     'shortText': 'New York',
#     'types': ['locality', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York County',
#     'shortText': 'New York County',
#     'types': ['administrative_area_level_2', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'New York',
#     'shortText': 'NY',
#     'types': ['administrative_area_level_1', 'political'],
#     'languageCode': 'en'},
#    {'longText': 'United States',
#     'shortText': 'US',
#     'types': ['country', 'political'],
#     'languageCode': 'en'},
#    {'longText': '10001',
#     'shortText': '10001',
#     'types': ['postal_code'],
#     'languageCode': 'en-US'}],
#   'plusCode': {'globalCode': '87G8Q232+54',
#    'compoundCode': 'Q232+54 New York, NY, USA'},
#   'location': {'latitude': 40.7528918, 'longitude': -73.99973709999999},
#   'viewport': {'low': {'latitude': 40.7516163197085,
#     'longitude': -74.0013554302915},
#    'high': {'latitude': 40.7543142802915, 'longitude': -73.99865746970849}},
#   'rating': 4.4,
#   'googleMapsUri': 'https://maps.google.com/?cid=3506101714971244648',
#   'websiteUri': 'https://www.wholefoodsmarket.com/stores/manhattanwest?utm_source=google&utm_medium=organic&utm_campaign=listings',
#   'regularOpeningHours': {'openNow': True,
#    'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 30},
#      'close': {'day': 0, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 1, 'hour': 7, 'minute': 30},
#      'close': {'day': 1, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 2, 'hour': 7, 'minute': 30},
#      'close': {'day': 2, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 3, 'hour': 7, 'minute': 30},
#      'close': {'day': 3, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 4, 'hour': 7, 'minute': 30},
#      'close': {'day': 4, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 5, 'hour': 7, 'minute': 30},
#      'close': {'day': 5, 'hour': 22, 'minute': 0}},
#     {'open': {'day': 6, 'hour': 7, 'minute': 30},
#      'close': {'day': 6, 'hour': 22, 'minute': 0}}],
#    'weekdayDescriptions': ['Monday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Tuesday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Wednesday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Thursday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Friday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Saturday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Sunday: 7:30\u202fAM\u2009–\u200910:00\u202fPM']},
#   'utcOffsetMinutes': -240,
#   'adrFormatAddress': '<span class="street-address">450 W 33rd St</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10001</span>, <span class="country-name">USA</span>',
#   'businessStatus': 'OPERATIONAL',
#   'userRatingCount': 768,
#   'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#   'iconBackgroundColor': '#4B96F3',
#   'displayName': {'text': 'Whole Foods Market', 'languageCode': 'en'},
#   'delivery': True,
#   'currentOpeningHours': {'openNow': True,
#    'periods': [{'open': {'day': 0,
#       'hour': 7,
#       'minute': 30,
#       'date': {'year': 2023, 'month': 10, 'day': 15}},
#      'close': {'day': 0,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 15}}},
#     {'open': {'day': 1,
#       'hour': 7,
#       'minute': 30,
#       'date': {'year': 2023, 'month': 10, 'day': 16}},
#      'close': {'day': 1,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 16}}},
#     {'open': {'day': 2,
#       'hour': 7,
#       'minute': 30,
#       'date': {'year': 2023, 'month': 10, 'day': 17}},
#      'close': {'day': 2,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 17}}},
#     {'open': {'day': 3,
#       'hour': 7,
#       'minute': 30,
#       'date': {'year': 2023, 'month': 10, 'day': 18}},
#      'close': {'day': 3,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 18}}},
#     {'open': {'day': 4,
#       'hour': 7,
#       'minute': 30,
#       'date': {'year': 2023, 'month': 10, 'day': 12}},
#      'close': {'day': 4,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 12}}},
#     {'open': {'day': 5,
#       'hour': 7,
#       'minute': 30,
#       'date': {'year': 2023, 'month': 10, 'day': 13}},
#      'close': {'day': 5,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 13}}},
#     {'open': {'day': 6,
#       'hour': 7,
#       'minute': 30,
#       'date': {'year': 2023, 'month': 10, 'day': 14}},
#      'close': {'day': 6,
#       'hour': 22,
#       'minute': 0,
#       'date': {'year': 2023, 'month': 10, 'day': 14}}}],
#    'weekdayDescriptions': ['Monday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Tuesday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Wednesday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Thursday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Friday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Saturday: 7:30\u202fAM\u2009–\u200910:00\u202fPM',
#     'Sunday: 7:30\u202fAM\u2009–\u200910:00\u202fPM']},
#   'editorialSummary': {'text': 'Eco-minded chain with natural & organic grocery items, housewares & other products (most sell wine).',
#    'languageCode': 'en'},
#   'reviews': [{'relativePublishTimeDescription': '3 months ago',
#     'rating': 5,
#     'text': {'text': 'My favorite whole Foods Market Best of all that is located on Manhattan West-here you have it all from cinema to restaurants, Pelton gym and so much more. Lots of activities here. Beautiful place with plenty of seats to eat outside and enjoy the fresh air.',
#      'languageCode': 'en'},
#     'originalText': {'text': 'My favorite whole Foods Market Best of all that is located on Manhattan West-here you have it all from cinema to restaurants, Pelton gym and so much more. Lots of activities here. Beautiful place with plenty of seats to eat outside and enjoy the fresh air.',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'Amanda R',
#      'uri': 'https://www.google.com/maps/contrib/101786107707431096955/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocJ5BdxkDQTWyPzGIGMvX7ekJQw-Dsn2uid6oNxb2gWO=s128-c0x00000000-cc-rp-mo-ba3'},
#     'publishTime': '2023-07-13T14:03:15Z'},
#    {'relativePublishTimeDescription': '5 months ago',
#     'rating': 2,
#     'text': {'text': "I couldn't sit down in the dining area to enjoy my breakfast again because of a homeless person who camps out for the day and stinks up the entire area (see photo). It is disgusting and Whole Foods management does nothing about it. Also, in the morning the employees who work in the produce area and the people who put delivery orders together are obnoxiously loud, yelling to each other and not acting like they are in a work environment. Otherwise, the store has everything I need,  but it's not a pleasant experience being in there. And they allow pet dogs, even though there are signs on the door prohibiting non service dogs.",
#      'languageCode': 'en'},
#     'originalText': {'text': "I couldn't sit down in the dining area to enjoy my breakfast again because of a homeless person who camps out for the day and stinks up the entire area (see photo). It is disgusting and Whole Foods management does nothing about it. Also, in the morning the employees who work in the produce area and the people who put delivery orders together are obnoxiously loud, yelling to each other and not acting like they are in a work environment. Otherwise, the store has everything I need,  but it's not a pleasant experience being in there. And they allow pet dogs, even though there are signs on the door prohibiting non service dogs.",
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'E',
#      'uri': 'https://www.google.com/maps/contrib/103204999921434384587/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocI4xqvLqQ0m2pXgnZY9xht2oL6cMetzLGD-i7dO0BIodA=s128-c0x00000000-cc-rp-mo'},
#     'publishTime': '2023-04-17T12:44:23Z'},
#    {'relativePublishTimeDescription': 'a week ago',
#     'rating': 5,
#     'text': {'text': 'Fantastic service by the staff.\nGood location and as with other branches, have a good variety if salads, pasta, soup, hot dishes, drinks. We created our own salad and I had a bit of the things I wanted to try and was happy with them.',
#      'languageCode': 'en'},
#     'originalText': {'text': 'Fantastic service by the staff.\nGood location and as with other branches, have a good variety if salads, pasta, soup, hot dishes, drinks. We created our own salad and I had a bit of the things I wanted to try and was happy with them.',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'MrsWayfarer',
#      'uri': 'https://www.google.com/maps/contrib/110534832290288175749/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjVqCWdHb2kuLyLEmALA9KUzL-XjEKJVURJu4Ac-QqC1FnQ=s128-c0x00000000-cc-rp-mo-ba6'},
#     'publishTime': '2023-10-01T23:32:53Z'},
#    {'relativePublishTimeDescription': 'a week ago',
#     'rating': 1,
#     'text': {'text': 'We bought hot food from this place and after we had it, my boyfriend was immediately had a diarrhea from it. I was not feeling so good my stomach was growling so much too. So we had to call this place. They said they will give us the refund. When I got in there, the people was really nice and give me back my receipt, but the manager come to my after and feels like he didn’t believe me, he said we had no complaints yet and want our info. I leave the phone number and name I don’t know if that legal for him to ask. But I have it anyway. This manager name is Omar. I never write any reviews on google, never get any food refund from Whole Foods. This one I had to, because I think it will be a different situation if I’m not a Asian women.',
#      'languageCode': 'en'},
#     'originalText': {'text': 'We bought hot food from this place and after we had it, my boyfriend was immediately had a diarrhea from it. I was not feeling so good my stomach was growling so much too. So we had to call this place. They said they will give us the refund. When I got in there, the people was really nice and give me back my receipt, but the manager come to my after and feels like he didn’t believe me, he said we had no complaints yet and want our info. I leave the phone number and name I don’t know if that legal for him to ask. But I have it anyway. This manager name is Omar. I never write any reviews on google, never get any food refund from Whole Foods. This one I had to, because I think it will be a different situation if I’m not a Asian women.',
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'jin li',
#      'uri': 'https://www.google.com/maps/contrib/109591799417691552205/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocKHEQImmY9b0JApdIlOAgRu1tkLDYLyuaLmLcCMMZSu=s128-c0x00000000-cc-rp-mo'},
#     'publishTime': '2023-10-03T01:52:42Z'},
#    {'relativePublishTimeDescription': '11 months ago',
#     'rating': 5,
#     'text': {'text': "This whole foods market is huge, thousands of product, verity of fish, meats , groceries. It's fresh cooked ready to eat food sanction is rich and plenty of different kind of food available. Rice is comparatively high, but considering the location, it's tolerable. Product quality high. It is by 1 and 2 Manhattan West, so, good tourist place too.",
#      'languageCode': 'en'},
#     'originalText': {'text': "This whole foods market is huge, thousands of product, verity of fish, meats , groceries. It's fresh cooked ready to eat food sanction is rich and plenty of different kind of food available. Rice is comparatively high, but considering the location, it's tolerable. Product quality high. It is by 1 and 2 Manhattan West, so, good tourist place too.",
#      'languageCode': 'en'},
#     'authorAttribution': {'displayName': 'SA Ahmed',
#      'uri': 'https://www.google.com/maps/contrib/102127021585291162704/reviews',
#      'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUEaLTANUIYtvF2GsyIjJcSWJzijiDSXqLnR1ddXfedBKs=s128-c0x00000000-cc-rp-mo-ba6'},
#     'publishTime': '2022-10-25T15:15:14Z'}],
#   'accessibilityOptions': {'wheelchairAccessibleEntrance': True}}]

# %%
def findlocationarea(prompt):
    myapikey = 'AIzaSyAHpf_Qy97E-SqC5GhEQqYIJrdB11IqkPg'
    url = 'https://places.googleapis.com/v1/places:searchText'
    headers = {
        'Content-Type': 'application/json',
        'X-Goog-Api-Key': myapikey,
        'X-Goog-FieldMask': 'places.displayName,places.rating,places.formattedAddress,places.viewport'
    }
    data = {
        'textQuery': 'Gyms near 72nd st in upper east side manhattan',
        'maxResultCount': 5
    }

# %%
import csv

def getlocationsfromcsv():
    myfile = 'DOITT_SUBWAY_STATION_01_13SEPT2010.csv'
    rows=[]
    with open(myfile, 'r') as file:
        csvreader = csv.reader(file)
        header = next(csvreader)
        for row in csvreader:
            rows.append(row[2:4])
            # rows.append(row[4])
    # print(header)
    print(rows)
    return rows

aasdfh = getlocationsfromcsv()
# Out:
# [['Astor Pl', 'POINT (-73.99106999861966 40.73005400028978)'], ['Canal St', 'POINT (-74.00019299927328 40.71880300107709)'], ['50th St', 'POINT (-73.98384899986625 40.76172799961419)'], ['Bergen St', 'POINT (-73.97499915116808 40.68086213682956)'], ['Pennsylvania Ave', 'POINT (-73.89488591154061 40.66471445143568)'], ['238th St', 'POINT (-73.90087000018522 40.88466700064975)'], ['Cathedral Pkwy (110th St)', 'POINT (-73.95806670661364 40.800581558114956)'], ['Kingston - Throop Aves', 'POINT (-73.94085899871263 40.67991899941601)'], ['65th St', 'POINT (-73.8987883783301 40.74971952935675)'], ['36th St', 'POINT (-73.92901818461539 40.75196004401078)'], ['Delancey St - Essex St', 'POINT (-73.98740940202974 40.71830605618619)'], ['Van Siclen Ave', 'POINT (-73.89165772702445 40.67802821447783)'], ['Norwood Ave', 'POINT (-73.87962599910783 40.68152000045683)'], ['104th-102nd Sts', 'POINT (-73.84443500029684 40.69516599823373)'], ['DeKalb Ave', 'POINT (-73.98177094440949 40.690648119969794)'], ['Beach 105th St', 'POINT (-73.82758075034528 40.58326843810286)'], ['Beach 90th St', 'POINT (-73.81365140419632 40.58809156457325)'], ['Freeman St', 'POINT (-73.89175225349464 40.829987446384116)'], ['Intervale Ave', 'POINT (-73.89661738461646 40.822142131170786)'], ['182nd-183rd Sts', 'POINT (-73.90074099998965 40.85609299881864)'], ['174th-175th Sts', 'POINT (-73.91013600050078 40.84589999983414)'], ['167th St', 'POINT (-73.91843200082253 40.83376899862797)'], ['Mets - Willets Point', 'POINT (-73.8456249984179 40.75462199881262)'], ['Junction Blvd', 'POINT (-73.86952700103515 40.74914499948836)'], ['Flushing - Main St', 'POINT (-73.83003000262508 40.75959999915012)'], ['Buhre Ave', 'POINT (-73.83256900003744 40.846809998885504)'], ['3rd Ave - 138th St', 'POINT (-73.92613800014134 40.81047600117261)'], ['Castle Hill Ave', 'POINT (-73.85122199961472 40.83425499825462)'], ['Brooklyn Bridge - City Hall', 'POINT (-74.0041310005885 40.713064999433136)'], ['Zerega Ave', 'POINT (-73.8470359987544 40.836488000608156)'], ['Grand Central - 42nd St', 'POINT (-73.9767132992584 40.75180742981634)'], ['33rd St', 'POINT (-73.98207600148947 40.74608099909145)'], ['96th St', 'POINT (-73.9510700015425 40.78567199998607)'], ['77th St', 'POINT (-73.95987399886047 40.77362000074615)'], ['Chauncey St', 'POINT (-73.91038357033376 40.68285130087804)'], ['Union St', 'POINT (-73.98310999909673 40.67731566735096)'], ['Elmhurst Ave', 'POINT (-73.8820347465864 40.74237007972169)'], ['Ralph Ave', 'POINT (-73.92078599933306 40.678822000873375)'], ['Pelham Pkwy', 'POINT (-73.86748067850041 40.8571924091606)'], ['Gun Hill Rd', 'POINT (-73.86613410538703 40.877839385172024)'], ['Nereid Ave (238 St)', 'POINT (-73.8543153107622 40.898286515575286)'], ['Franklin Ave', 'POINT (-73.9580997367769 40.67076515344894)'], ['Simpson St', 'POINT (-73.89306639507903 40.823976841237396)'], ['Bronx Park East', 'POINT (-73.86835609178098 40.848768666338934)'], ['Winthrop St', 'POINT (-73.95007934590994 40.65665931376077)'], ['Van Siclen Ave', 'POINT (-73.88940491730106 40.665517963059635)'], ['149th St - Grand Concourse', 'POINT (-73.9273847542618 40.81830344372315)'], ['161st St - Yankee Stadium', 'POINT (-73.92569199505733 40.82823032742169)'], ['Lexington Ave - 59th St', 'POINT (-73.9679670004732 40.762526000304575)'], ['E 149th St', 'POINT (-73.90409799875945 40.81211799827203)'], ['Morrison Av - Soundview', 'POINT (-73.87451599929486 40.82952100156747)'], ['Whitlock Ave', 'POINT (-73.8862829985325 40.82652500055904)'], ['St Lawrence Ave', 'POINT (-73.86761799923673 40.8315090005233)'], ['Woodside - 61st St', 'POINT (-73.90298400173006 40.745630001138395)'], ['Far Rockaway - Mott Ave', 'POINT (-73.75540499924732 40.603995001687544)'], ['72nd St', 'POINT (-73.976336575218 40.77551939729258)'], ['96th St', 'POINT (-73.96460245687166 40.79161879767014)'], ['168th St', 'POINT (-73.93956099985425 40.84071899990795)'], ['Kingsbridge Rd', 'POINT (-73.8935090000331 40.86697799999945)'], ['42nd St ...

# %%
# Method will take each location listed in the csv and parse latitude and longitude from it
# Then requests a search of shops in that location near the coordinates, based on the search param and radius
def findspotsnearlocation():
    # location = getlocationsfromcsv()
    location = aasdfh
    # print(len(location)) 
    # len is 473 stations
    counter = 0 
    while counter<10:
        # print(location[counter][1])
        stationname = location[counter][0]
        latlong = location[counter][1].split(" ")
        longitude = float(latlong[1][1:])
        latitude= float(latlong[2][:-1])
        print("Station " + stationname + " is at: " + str(latitude) + ", " + str(longitude))
        searchparam = "grocery stores"
        radius = 5.0
        search = locationtextsearchrequest(stationname, latitude, longitude, radius, searchparam)
        counter = counter+1
    
    return search


test = findspotsnearlocation()
# Out:
# Station Astor Pl is at: 40.73005400028978, -73.99106999861966
# {'places': [{'name': 'places/ChIJ3xZbsp5ZwokRRvzkWV-pP1U', 'id': 'ChIJ3xZbsp5ZwokRRvzkWV-pP1U', 'types': ['grocery_store', 'point_of_interest', 'food', 'store', 'establishment'], 'nationalPhoneNumber': '(212) 253-8400', 'internationalPhoneNumber': '+1 212-253-8400', 'formattedAddress': '84 3rd Ave, New York, NY 10003, USA', 'addressComponents': [{'longText': '84', 'shortText': '84', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': '3rd Avenue', 'shortText': '3rd Ave', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Manhattan', 'shortText': 'Manhattan', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'New York', 'types': ['locality', 'political'], 'languageCode': 'en'}, {'longText': 'New York County', 'shortText': 'New York County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '10003', 'shortText': '10003', 'types': ['postal_code'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8P2J6+PG', 'compoundCode': 'P2J6+PG New York, NY, USA'}, 'location': {'latitude': 40.7318431, 'longitude': -73.98865459999999}, 'viewport': {'low': {'latitude': 40.730475869708506, 'longitude': -73.9898146302915}, 'high': {'latitude': 40.733173830291506, 'longitude': -73.9871166697085}}, 'rating': 4.4, 'googleMapsUri': 'https://maps.google.com/?cid=6142814643751812166', 'websiteUri': 'https://wmarketnyc.com/84-third-avenue/?utm_source=gmb&utm_medium=Yext', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 0, 'minute': 0}}], 'weekdayDescriptions': ['Monday: Open 24 hours', 'Tuesday: Open 24 hours', 'Wednesday: Open 24 hours', 'Thursday: Open 24 hours', 'Friday: Open 24 hours', 'Saturday: Open 24 hours', 'Sunday: Open 24 hours']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">84 3rd Ave</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10003</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'priceLevel': 'PRICE_LEVEL_MODERATE', 'userRatingCount': 839, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'Westside Market NYC', 'languageCode': 'en'}, 'delivery': True, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 4, 'hour': 0, 'minute': 0, 'truncated': True, 'date': {'year': 2023, 'month': 10, 'day': 12}}, 'close': {'day': 3, 'hour': 23, 'minute': 59, 'truncated': True, 'date': {'year': 2023, 'month': 10, 'day': 18}}}], 'weekdayDescriptions': ['Monday: Open 24 hours', 'Tuesday: Open 24 hours', 'Wednesday: Open 24 hours', 'Thursday: Open 24 hours', 'Friday: Open 24 hours', 'Saturday: Open 24 hours', 'Sunday: Open 24 hours']}, 'editorialSummary': {'text': 'Sharp market with an informal feel stocking meat & produce, plus gourmet & prepared foods.', 'languageCode': 'en'}, 'reviews': [{'relativePublishTimeDescription': 'a month ago', 'rating': 5, 'text': {'text': 'My go to place for late night grocery pick up.  This supermarket is freezing cold regardless of the season outside. I think it discourage people from hanging around too long and just pick up and go.  The check out is fast and no-nonsense. Vegetables and fruits are fresh as they come.', 'languageCode': 'en'}, 'originalText': {'text': 'My go to place for late night grocery pick up.  This supermarket is freezing cold regardless of the season outside. I think it discourage people from hanging around too long and just pick up and go.  The check out is fast and no-nonsense. Vegetables and fruits are fresh as they come.', 'languageCode': 'en'}, 'authorAttribution ...
# Station Canal St is at: 40.71880300107709, -74.00019299927328
# {'places': [{'name': 'places/ChIJ9xbqYYhZwokR-JbUtPyRtb0', 'id': 'ChIJ9xbqYYhZwokR-JbUtPyRtb0', 'types': ['grocery_store', 'food', 'point_of_interest', 'store', 'establishment'], 'nationalPhoneNumber': '(212) 965-0692', 'internationalPhoneNumber': '+1 212-965-0692', 'formattedAddress': '162 Mott St, New York, NY 10013, USA', 'addressComponents': [{'longText': '162', 'shortText': '162', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'Mott Street', 'shortText': 'Mott St', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Manhattan', 'shortText': 'Manhattan', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'New York', 'types': ['locality', 'political'], 'languageCode': 'en'}, {'longText': 'New York County', 'shortText': 'New York County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '10013', 'shortText': '10013', 'types': ['postal_code'], 'languageCode': 'en-US'}, {'longText': '5425', 'shortText': '5425', 'types': ['postal_code_suffix'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8P293+RJ', 'compoundCode': 'P293+RJ New York, NY, USA'}, 'location': {'latitude': 40.719605, 'longitude': -73.995969}, 'viewport': {'low': {'latitude': 40.71829081970851, 'longitude': -73.99745578029152}, 'high': {'latitude': 40.720988780291506, 'longitude': -73.9947578197085}}, 'rating': 5, 'googleMapsUri': 'https://maps.google.com/?cid=13669992758504625912', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 9, 'minute': 0}, 'close': {'day': 0, 'hour': 17, 'minute': 30}}, {'open': {'day': 1, 'hour': 9, 'minute': 0}, 'close': {'day': 1, 'hour': 17, 'minute': 30}}, {'open': {'day': 2, 'hour': 9, 'minute': 0}, 'close': {'day': 2, 'hour': 17, 'minute': 30}}, {'open': {'day': 3, 'hour': 9, 'minute': 0}, 'close': {'day': 3, 'hour': 17, 'minute': 30}}, {'open': {'day': 4, 'hour': 9, 'minute': 0}, 'close': {'day': 4, 'hour': 17, 'minute': 30}}, {'open': {'day': 5, 'hour': 9, 'minute': 0}, 'close': {'day': 5, 'hour': 17, 'minute': 30}}, {'open': {'day': 6, 'hour': 9, 'minute': 0}, 'close': {'day': 6, 'hour': 17, 'minute': 30}}], 'weekdayDescriptions': ['Monday: 9:00\u202fAM\u2009–\u20095:30\u202fPM', 'Tuesday: 9:00\u202fAM\u2009–\u20095:30\u202fPM', 'Wednesday: 9:00\u202fAM\u2009–\u20095:30\u202fPM', 'Thursday: 9:00\u202fAM\u2009–\u20095:30\u202fPM', 'Friday: 9:00\u202fAM\u2009–\u20095:30\u202fPM', 'Saturday: 9:00\u202fAM\u2009–\u20095:30\u202fPM', 'Sunday: 9:00\u202fAM\u2009–\u20095:30\u202fPM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">162 Mott St</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10013-5425</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 7, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'Grand Win Supermarket Inc', 'languageCode': 'en'}, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 9, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 0, 'hour': 17, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 15}}}, {'open': {'day': 1, 'hour': 9, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 1, 'hour': 17, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 2, 'hour': 9, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 2, 'hour': 17, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'open': {'day': 3, 'hour': 9, 'minute' ...
# Station 50th St is at: 40.76172799961419, -73.98384899986625
# {'places': [{'name': 'places/ChIJuWO59FZYwokRDbvnB6y8iBg', 'id': 'ChIJuWO59FZYwokRDbvnB6y8iBg', 'types': ['grocery_store', 'supermarket', 'store', 'food', 'point_of_interest', 'establishment'], 'nationalPhoneNumber': '(212) 977-1710', 'internationalPhoneNumber': '+1 212-977-1710', 'formattedAddress': '810 8th Ave, New York, NY 10019, USA', 'addressComponents': [{'longText': '810', 'shortText': '810', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': '8th Avenue', 'shortText': '8th Ave', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Manhattan', 'shortText': 'Manhattan', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'New York', 'types': ['locality', 'political'], 'languageCode': 'en'}, {'longText': 'New York County', 'shortText': 'New York County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '10019', 'shortText': '10019', 'types': ['postal_code'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8Q267+MG', 'compoundCode': 'Q267+MG New York, NY, USA'}, 'location': {'latitude': 40.7617385, 'longitude': -73.98619040000001}, 'viewport': {'low': {'latitude': 40.76040141970851, 'longitude': -73.98717863029151}, 'high': {'latitude': 40.76309938029151, 'longitude': -73.98448066970849}}, 'rating': 4, 'googleMapsUri': 'https://maps.google.com/?cid=1767870300795943693', 'websiteUri': 'http://www.shopfoodemporium.com/', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0}, 'close': {'day': 1, 'hour': 0, 'minute': 0}}, {'open': {'day': 1, 'hour': 7, 'minute': 0}, 'close': {'day': 2, 'hour': 0, 'minute': 0}}, {'open': {'day': 2, 'hour': 7, 'minute': 0}, 'close': {'day': 3, 'hour': 0, 'minute': 0}}, {'open': {'day': 3, 'hour': 7, 'minute': 0}, 'close': {'day': 4, 'hour': 0, 'minute': 0}}, {'open': {'day': 4, 'hour': 7, 'minute': 0}, 'close': {'day': 5, 'hour': 0, 'minute': 0}}, {'open': {'day': 5, 'hour': 7, 'minute': 0}, 'close': {'day': 6, 'hour': 1, 'minute': 0}}, {'open': {'day': 6, 'hour': 7, 'minute': 0}, 'close': {'day': 0, 'hour': 1, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u200912:00\u202fAM', 'Tuesday: 7:00\u202fAM\u2009–\u200912:00\u202fAM', 'Wednesday: 7:00\u202fAM\u2009–\u200912:00\u202fAM', 'Thursday: 7:00\u202fAM\u2009–\u200912:00\u202fAM', 'Friday: 7:00\u202fAM\u2009–\u20091:00\u202fAM', 'Saturday: 7:00\u202fAM\u2009–\u20091:00\u202fAM', 'Sunday: 7:00\u202fAM\u2009–\u200912:00\u202fAM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">810 8th Ave</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10019</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 1410, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'The Food Emporium & Amish Kitchen', 'languageCode': 'en'}, 'takeout': True, 'delivery': True, 'curbsidePickup': True, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 1, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 1, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 2, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'open': {'day': 2, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 3, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 18}}}, {'open': {'day': 3 ...
# Station Bergen St is at: 40.68086213682956, -73.97499915116808
# {'places': [{'name': 'places/ChIJWTaJ1KhbwokRnieGTprn3eY', 'id': 'ChIJWTaJ1KhbwokRnieGTprn3eY', 'types': ['grocery_store', 'food', 'point_of_interest', 'store', 'establishment'], 'nationalPhoneNumber': '(718) 783-3300', 'internationalPhoneNumber': '+1 718-783-3300', 'formattedAddress': '271 Flatbush Ave, Brooklyn, NY 11217, USA', 'addressComponents': [{'longText': '271', 'shortText': '271', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'Flatbush Avenue', 'shortText': 'Flatbush Ave', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Prospect Heights', 'shortText': 'Prospect Heights', 'types': ['neighborhood', 'political'], 'languageCode': 'en'}, {'longText': 'Brooklyn', 'shortText': 'Brooklyn', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'Kings County', 'shortText': 'Kings County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '11217', 'shortText': '11217', 'types': ['postal_code'], 'languageCode': 'en-US'}, {'longText': '2821', 'shortText': '2821', 'types': ['postal_code_suffix'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8M2HG+RC', 'compoundCode': 'M2HG+RC New York, NY, USA'}, 'location': {'latitude': 40.6795194, 'longitude': -73.9738825}, 'viewport': {'low': {'latitude': 40.6781117197085, 'longitude': -73.97532913029151}, 'high': {'latitude': 40.680809680291496, 'longitude': -73.97263116970849}}, 'rating': 4.3, 'googleMapsUri': 'https://maps.google.com/?cid=16635707248504874910', 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">271 Flatbush Ave</span>, <span class="locality">Brooklyn</span>, <span class="region">NY</span> <span class="postal-code">11217-2821</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 16, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'The Market Place', 'languageCode': 'en'}, 'reviews': [{'relativePublishTimeDescription': 'a year ago', 'rating': 5, 'text': {'text': 'The staff is really friendly and helpful! Best bodega in the neighborhood if you ask me\nGreat selection of beers as well', 'languageCode': 'en'}, 'originalText': {'text': 'The staff is really friendly and helpful! Best bodega in the neighborhood if you ask me\nGreat selection of beers as well', 'languageCode': 'en'}, 'authorAttribution': {'displayName': 'Adrien Cadet', 'uri': 'https://www.google.com/maps/contrib/106328091000607917357/reviews', 'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocKtoFF_qW08nhLAXTn6Mq1vlzwnccTxsg61PcYXhDtN=s128-c0x00000000-cc-rp-mo-ba4'}, 'publishTime': '2021-12-14T21:50:19Z'}, {'relativePublishTimeDescription': '4 years ago', 'rating': 5, 'text': {'text': 'Nice family owned bodega. They are very friendly and helpful. Have a wide selection of high quality food.', 'languageCode': 'en'}, 'originalText': {'text': 'Nice family owned bodega. They are very friendly and helpful. Have a wide selection of high quality food.', 'languageCode': 'en'}, 'authorAttribution': {'displayName': 'Bella Lewis', 'uri': 'https://www.google.com/maps/contrib/106735308459136923747/reviews', 'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjXw1w1hPIe32PwHjkjzG9_xm0gbbhgna_9_ucT1LVCU2CQ=s128-c0x00000000-cc-rp-mo-ba4'}, 'publishTime': '2019-03-24T12:19:40Z'}, {'relativePublishTimeDescription': '4 months ago', 'rating': 4, 'text': {'text': 'Super friendly with a plethora of products', 'languageCode': 'en'}, 'originalText': {'text': 'Super friendly with a plethora of products', 'languageCode': 'en'}, 'authorAttribution': {'displayName': 'Chantz johnson', 'uri': 'https://www.google.com/ ...
# Station Pennsylvania Ave is at: 40.66471445143568, -73.89488591154061
# {'places': [{'name': 'places/ChIJC4uqr1VcwokR9_dyDBec2E0', 'id': 'ChIJC4uqr1VcwokR9_dyDBec2E0', 'types': ['grocery_store', 'food', 'store', 'point_of_interest', 'establishment'], 'nationalPhoneNumber': '(347) 425-9833', 'internationalPhoneNumber': '+1 347-425-9833', 'formattedAddress': '580 Vermont St, Brooklyn, NY 11207, USA', 'addressComponents': [{'longText': '580', 'shortText': '580', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'Vermont Street', 'shortText': 'Vermont St', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'East New York', 'shortText': 'East New York', 'types': ['neighborhood', 'political'], 'languageCode': 'en'}, {'longText': 'Brooklyn', 'shortText': 'Brooklyn', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'Kings County', 'shortText': 'Kings County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '11207', 'shortText': '11207', 'types': ['postal_code'], 'languageCode': 'en-US'}, {'longText': '5410', 'shortText': '5410', 'types': ['postal_code_suffix'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8M485+22', 'compoundCode': 'M485+22 New York, NY, USA'}, 'location': {'latitude': 40.665116999999995, 'longitude': -73.89244599999999}, 'viewport': {'low': {'latitude': 40.66372466970851, 'longitude': -73.89372163029151}, 'high': {'latitude': 40.6664226302915, 'longitude': -73.89102366970849}}, 'rating': 3.9, 'googleMapsUri': 'https://maps.google.com/?cid=5609404958696994807', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 6, 'minute': 0}, 'close': {'day': 0, 'hour': 22, 'minute': 0}}, {'open': {'day': 1, 'hour': 6, 'minute': 0}, 'close': {'day': 1, 'hour': 22, 'minute': 0}}, {'open': {'day': 2, 'hour': 6, 'minute': 0}, 'close': {'day': 2, 'hour': 22, 'minute': 0}}, {'open': {'day': 3, 'hour': 6, 'minute': 0}, 'close': {'day': 3, 'hour': 22, 'minute': 0}}, {'open': {'day': 4, 'hour': 6, 'minute': 0}, 'close': {'day': 4, 'hour': 22, 'minute': 0}}, {'open': {'day': 5, 'hour': 6, 'minute': 0}, 'close': {'day': 5, 'hour': 22, 'minute': 0}}, {'open': {'day': 6, 'hour': 6, 'minute': 0}, 'close': {'day': 6, 'hour': 22, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 6:00\u202fAM\u2009–\u200910:00\u202fPM', 'Tuesday: 6:00\u202fAM\u2009–\u200910:00\u202fPM', 'Wednesday: 6:00\u202fAM\u2009–\u200910:00\u202fPM', 'Thursday: 6:00\u202fAM\u2009–\u200910:00\u202fPM', 'Friday: 6:00\u202fAM\u2009–\u200910:00\u202fPM', 'Saturday: 6:00\u202fAM\u2009–\u200910:00\u202fPM', 'Sunday: 6:00\u202fAM\u2009–\u200910:00\u202fPM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">580 Vermont St</span>, <span class="locality">Brooklyn</span>, <span class="region">NY</span> <span class="postal-code">11207-5410</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 30, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'Vermont Gourmet Deli Grocery', 'languageCode': 'en'}, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 6, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 0, 'hour': 22, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}}, {'open': {'day': 1, 'hour': 6, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 1, 'hour': 22, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 2, 'hour': 6, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 2, 'hour': 22, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'o ...
# Station 238th St is at: 40.88466700064975, -73.90087000018522
# {'places': [{'name': 'places/ChIJkySsPqPzwokRIGbb83d-yho', 'id': 'ChIJkySsPqPzwokRIGbb83d-yho', 'types': ['grocery_store', 'convenience_store', 'store', 'food', 'point_of_interest', 'establishment'], 'nationalPhoneNumber': '(718) 543-4949', 'internationalPhoneNumber': '+1 718-543-4949', 'formattedAddress': '210 W 238th St, Bronx, NY 10463, USA', 'addressComponents': [{'longText': '210', 'shortText': '210', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'West 238th Street', 'shortText': 'W 238th St', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Kingsbridge', 'shortText': 'Kingsbridge', 'types': ['neighborhood', 'political'], 'languageCode': 'en'}, {'longText': 'The Bronx', 'shortText': 'Bronx', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'Bronx County', 'shortText': 'Bronx County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '10463', 'shortText': '10463', 'types': ['postal_code'], 'languageCode': 'en-US'}, {'longText': '2408', 'shortText': '2408', 'types': ['postal_code_suffix'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8V4M2+V5', 'compoundCode': 'V4M2+V5 The Bronx, NY, USA'}, 'location': {'latitude': 40.884656799999995, 'longitude': -73.899554}, 'viewport': {'low': {'latitude': 40.88336161970851, 'longitude': -73.90091533029151}, 'high': {'latitude': 40.8860595802915, 'longitude': -73.89821736970849}}, 'rating': 4.9, 'googleMapsUri': 'https://maps.google.com/?cid=1930494443939128864', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 30}, 'close': {'day': 1, 'hour': 0, 'minute': 0}}, {'open': {'day': 1, 'hour': 8, 'minute': 30}, 'close': {'day': 2, 'hour': 0, 'minute': 0}}, {'open': {'day': 2, 'hour': 8, 'minute': 30}, 'close': {'day': 3, 'hour': 0, 'minute': 0}}, {'open': {'day': 3, 'hour': 8, 'minute': 30}, 'close': {'day': 4, 'hour': 0, 'minute': 0}}, {'open': {'day': 4, 'hour': 8, 'minute': 30}, 'close': {'day': 5, 'hour': 0, 'minute': 0}}, {'open': {'day': 5, 'hour': 8, 'minute': 30}, 'close': {'day': 6, 'hour': 0, 'minute': 0}}, {'open': {'day': 6, 'hour': 8, 'minute': 30}, 'close': {'day': 0, 'hour': 0, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 8:30\u202fAM\u2009–\u200912:00\u202fAM', 'Tuesday: 8:30\u202fAM\u2009–\u200912:00\u202fAM', 'Wednesday: 8:30\u202fAM\u2009–\u200912:00\u202fAM', 'Thursday: 8:30\u202fAM\u2009–\u200912:00\u202fAM', 'Friday: 8:30\u202fAM\u2009–\u200912:00\u202fAM', 'Saturday: 8:30\u202fAM\u2009–\u200912:00\u202fAM', 'Sunday: 8:30\u202fAM\u2009–\u200912:00\u202fAM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">210 W 238th St</span>, <span class="locality">Bronx</span>, <span class="region">NY</span> <span class="postal-code">10463-2408</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 7, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': "Vargas Grocery's", 'languageCode': 'en'}, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 1, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 1, 'hour': 8, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 2, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'open': {'day': 2, 'hour': 8, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 3, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 18}}}, {'open': {' ...
# Station Cathedral Pkwy (110th St) is at: 40.800581558114956, -73.95806670661364
# {'places': [{'name': 'places/ChIJYX8zqiL2wokRlvbqSyfohm0', 'id': 'ChIJYX8zqiL2wokRlvbqSyfohm0', 'types': ['supermarket', 'grocery_store', 'store', 'food', 'point_of_interest', 'establishment'], 'nationalPhoneNumber': '(212) 932-1990', 'internationalPhoneNumber': '+1 212-932-1990', 'formattedAddress': '300 W 110th St, New York, NY 10025, USA', 'addressComponents': [{'longText': '300', 'shortText': '300', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'West 110th Street', 'shortText': 'W 110th St', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Manhattan', 'shortText': 'Manhattan', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'New York', 'types': ['locality', 'political'], 'languageCode': 'en'}, {'longText': 'New York County', 'shortText': 'New York County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '10025', 'shortText': '10025', 'types': ['postal_code'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8R22R+87', 'compoundCode': 'R22R+87 New York, NY, USA'}, 'location': {'latitude': 40.8008246, 'longitude': -73.9593431}, 'viewport': {'low': {'latitude': 40.7994902197085, 'longitude': -73.9606010802915}, 'high': {'latitude': 40.802188180291495, 'longitude': -73.95790311970849}}, 'rating': 3.8, 'googleMapsUri': 'https://maps.google.com/?cid=7892250652488431254', 'websiteUri': 'http://www.centralmarketsnyc.com/', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 0}, 'close': {'day': 0, 'hour': 20, 'minute': 0}}, {'open': {'day': 1, 'hour': 8, 'minute': 0}, 'close': {'day': 1, 'hour': 20, 'minute': 0}}, {'open': {'day': 2, 'hour': 8, 'minute': 0}, 'close': {'day': 2, 'hour': 20, 'minute': 0}}, {'open': {'day': 3, 'hour': 8, 'minute': 0}, 'close': {'day': 3, 'hour': 20, 'minute': 0}}, {'open': {'day': 4, 'hour': 8, 'minute': 0}, 'close': {'day': 4, 'hour': 20, 'minute': 0}}, {'open': {'day': 5, 'hour': 8, 'minute': 0}, 'close': {'day': 5, 'hour': 20, 'minute': 0}}, {'open': {'day': 6, 'hour': 8, 'minute': 0}, 'close': {'day': 6, 'hour': 20, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 8:00\u202fAM\u2009–\u20098:00\u202fPM', 'Tuesday: 8:00\u202fAM\u2009–\u20098:00\u202fPM', 'Wednesday: 8:00\u202fAM\u2009–\u20098:00\u202fPM', 'Thursday: 8:00\u202fAM\u2009–\u20098:00\u202fPM', 'Friday: 8:00\u202fAM\u2009–\u20098:00\u202fPM', 'Saturday: 8:00\u202fAM\u2009–\u20098:00\u202fPM', 'Sunday: 8:00\u202fAM\u2009–\u20098:00\u202fPM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">300 W 110th St</span>, <span class="locality">New York</span>, <span class="region">NY</span> <span class="postal-code">10025</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 304, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'Central Markets', 'languageCode': 'en'}, 'delivery': True, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 0, 'hour': 20, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}}, {'open': {'day': 1, 'hour': 8, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 1, 'hour': 20, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 2, 'hour': 8, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 2, 'hour': 20, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'open': {'day': 3, 'hour': 8, 'minute': 0, 'date': {'year': 2 ...
# Station Kingston - Throop Aves is at: 40.67991899941601, -73.94085899871263
# {'places': [{'name': 'places/ChIJAQ3JuxdbwokRF-dQgTbBwpc', 'id': 'ChIJAQ3JuxdbwokRF-dQgTbBwpc', 'types': ['grocery_store', 'food', 'point_of_interest', 'store', 'establishment'], 'nationalPhoneNumber': '(718) 399-1673', 'internationalPhoneNumber': '+1 718-399-1673', 'formattedAddress': '73 Decatur St, Brooklyn, NY 11216, USA', 'addressComponents': [{'longText': '73', 'shortText': '73', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'Decatur Street', 'shortText': 'Decatur St', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Stuyvesant Heights', 'shortText': 'Stuyvesant Heights', 'types': ['neighborhood', 'political'], 'languageCode': 'en'}, {'longText': 'Brooklyn', 'shortText': 'Brooklyn', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'Kings County', 'shortText': 'Kings County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '11216', 'shortText': '11216', 'types': ['postal_code'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8M3J5+8P', 'compoundCode': 'M3J5+8P New York, NY, USA'}, 'location': {'latitude': 40.6807951, 'longitude': -73.9406863}, 'viewport': {'low': {'latitude': 40.6793594197085, 'longitude': -73.94201793029151}, 'high': {'latitude': 40.682057380291496, 'longitude': -73.9393199697085}}, 'rating': 3.8, 'googleMapsUri': 'https://maps.google.com/?cid=10935515285050943255', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 6, 'minute': 30}, 'close': {'day': 1, 'hour': 0, 'minute': 0}}, {'open': {'day': 1, 'hour': 6, 'minute': 30}, 'close': {'day': 2, 'hour': 0, 'minute': 0}}, {'open': {'day': 2, 'hour': 6, 'minute': 30}, 'close': {'day': 3, 'hour': 0, 'minute': 0}}, {'open': {'day': 3, 'hour': 6, 'minute': 30}, 'close': {'day': 4, 'hour': 0, 'minute': 0}}, {'open': {'day': 4, 'hour': 6, 'minute': 30}, 'close': {'day': 5, 'hour': 0, 'minute': 0}}, {'open': {'day': 5, 'hour': 6, 'minute': 30}, 'close': {'day': 6, 'hour': 0, 'minute': 0}}, {'open': {'day': 6, 'hour': 6, 'minute': 30}, 'close': {'day': 0, 'hour': 0, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 6:30\u202fAM\u2009–\u200912:00\u202fAM', 'Tuesday: 6:30\u202fAM\u2009–\u200912:00\u202fAM', 'Wednesday: 6:30\u202fAM\u2009–\u200912:00\u202fAM', 'Thursday: 6:30\u202fAM\u2009–\u200912:00\u202fAM', 'Friday: 6:30\u202fAM\u2009–\u200912:00\u202fAM', 'Saturday: 6:30\u202fAM\u2009–\u200912:00\u202fAM', 'Sunday: 6:30\u202fAM\u2009–\u200912:00\u202fAM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">73 Decatur St</span>, <span class="locality">Brooklyn</span>, <span class="region">NY</span> <span class="postal-code">11216</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 4, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': '73 food market', 'languageCode': 'en'}, 'delivery': True, 'curbsidePickup': True, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 6, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 1, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 1, 'hour': 6, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 2, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'open': {'day': 2, 'hour': 6, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 3, 'hour': 0, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 18}}}, {'open': {'day': 3, 'hour': 6, 'minute': 30, 'date': {'year': 2023, 'month': 10, 'day': 18 ...
# Station 65th St is at: 40.74971952935675, -73.8987883783301
# {'places': [{'name': 'places/ChIJraL86ARfwokRpAnywU_Ic20', 'id': 'ChIJraL86ARfwokRpAnywU_Ic20', 'types': ['grocery_store', 'food', 'point_of_interest', 'store', 'establishment'], 'formattedAddress': '6304 Broadway, Flushing, NY 11377, USA', 'addressComponents': [{'longText': '6304', 'shortText': '6304', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'Broadway', 'shortText': 'Broadway', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Flushing', 'shortText': 'Flushing', 'types': ['neighborhood', 'political'], 'languageCode': 'en'}, {'longText': 'Queens', 'shortText': 'Queens', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'Queens County', 'shortText': 'Queens County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '11377', 'shortText': '11377', 'types': ['postal_code'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8P4X2+W9', 'compoundCode': 'P4X2+W9 Flushing, Queens, NY, USA'}, 'location': {'latitude': 40.7497784, 'longitude': -73.8990227}, 'viewport': {'low': {'latitude': 40.7484854197085, 'longitude': -73.9003287302915}, 'high': {'latitude': 40.7511833802915, 'longitude': -73.8976307697085}}, 'rating': 4.5, 'googleMapsUri': 'https://maps.google.com/?cid=7886867617337706916', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 0}, 'close': {'day': 0, 'hour': 21, 'minute': 0}}, {'open': {'day': 1, 'hour': 8, 'minute': 0}, 'close': {'day': 1, 'hour': 21, 'minute': 0}}, {'open': {'day': 2, 'hour': 8, 'minute': 0}, 'close': {'day': 2, 'hour': 21, 'minute': 0}}, {'open': {'day': 3, 'hour': 8, 'minute': 0}, 'close': {'day': 3, 'hour': 21, 'minute': 0}}, {'open': {'day': 4, 'hour': 8, 'minute': 0}, 'close': {'day': 4, 'hour': 21, 'minute': 0}}, {'open': {'day': 5, 'hour': 8, 'minute': 0}, 'close': {'day': 5, 'hour': 21, 'minute': 0}}, {'open': {'day': 6, 'hour': 8, 'minute': 0}, 'close': {'day': 6, 'hour': 21, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 8:00\u202fAM\u2009–\u20099:00\u202fPM', 'Tuesday: 8:00\u202fAM\u2009–\u20099:00\u202fPM', 'Wednesday: 8:00\u202fAM\u2009–\u20099:00\u202fPM', 'Thursday: 8:00\u202fAM\u2009–\u20099:00\u202fPM', 'Friday: 8:00\u202fAM\u2009–\u20099:00\u202fPM', 'Saturday: 8:00\u202fAM\u2009–\u20099:00\u202fPM', 'Sunday: 8:00\u202fAM\u2009–\u20099:00\u202fPM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">6304 Broadway</span>, <span class="locality">Flushing</span>, <span class="region">NY</span> <span class="postal-code">11377</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 2, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'Rositas Grocery', 'languageCode': 'en'}, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 8, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 0, 'hour': 21, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}}, {'open': {'day': 1, 'hour': 8, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 1, 'hour': 21, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 2, 'hour': 8, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 2, 'hour': 21, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'open': {'day': 3, 'hour': 8, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 18}}, 'close': {'day': 3, 'hour': 21, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 18}}}, {'open': {'day': 4, 'hour': 8, 'minute': 0, 'date': {'year': ...
# Station 36th St is at: 40.75196004401078, -73.92901818461539
# {'places': [{'name': 'places/ChIJXzhOvqtZwokRSOOfSdybUvM', 'id': 'ChIJXzhOvqtZwokRSOOfSdybUvM', 'types': ['grocery_store', 'market', 'store', 'food', 'point_of_interest', 'establishment'], 'nationalPhoneNumber': '(718) 392-2406', 'internationalPhoneNumber': '+1 718-392-2406', 'formattedAddress': '29-18 Queens Plaza S, Queens, NY 11101, USA', 'addressComponents': [{'longText': '29-18', 'shortText': '29-18', 'types': ['street_number'], 'languageCode': 'en-US'}, {'longText': 'Queens Plaza South', 'shortText': 'Queens Plaza S', 'types': ['route'], 'languageCode': 'en'}, {'longText': 'Long Island City', 'shortText': 'LIC', 'types': ['neighborhood', 'political'], 'languageCode': 'en'}, {'longText': 'Queens', 'shortText': 'Queens', 'types': ['sublocality_level_1', 'sublocality', 'political'], 'languageCode': 'en'}, {'longText': 'Queens County', 'shortText': 'Queens County', 'types': ['administrative_area_level_2', 'political'], 'languageCode': 'en'}, {'longText': 'New York', 'shortText': 'NY', 'types': ['administrative_area_level_1', 'political'], 'languageCode': 'en'}, {'longText': 'United States', 'shortText': 'US', 'types': ['country', 'political'], 'languageCode': 'en'}, {'longText': '11101', 'shortText': '11101', 'types': ['postal_code'], 'languageCode': 'en-US'}], 'plusCode': {'globalCode': '87G8P3X6+JP', 'compoundCode': 'P3X6+JP New York, NY, USA'}, 'location': {'latitude': 40.7490586, 'longitude': -73.9382112}, 'viewport': {'low': {'latitude': 40.7477967197085, 'longitude': -73.9394027802915}, 'high': {'latitude': 40.750494680291496, 'longitude': -73.9367048197085}}, 'rating': 4.1, 'googleMapsUri': 'https://maps.google.com/?cid=17533247669737087816', 'websiteUri': 'http://cityacresmarket.com/', 'regularOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0}, 'close': {'day': 0, 'hour': 23, 'minute': 0}}, {'open': {'day': 1, 'hour': 7, 'minute': 0}, 'close': {'day': 1, 'hour': 23, 'minute': 0}}, {'open': {'day': 2, 'hour': 7, 'minute': 0}, 'close': {'day': 2, 'hour': 23, 'minute': 0}}, {'open': {'day': 3, 'hour': 7, 'minute': 0}, 'close': {'day': 3, 'hour': 23, 'minute': 0}}, {'open': {'day': 4, 'hour': 7, 'minute': 0}, 'close': {'day': 4, 'hour': 23, 'minute': 0}}, {'open': {'day': 5, 'hour': 7, 'minute': 0}, 'close': {'day': 5, 'hour': 23, 'minute': 0}}, {'open': {'day': 6, 'hour': 7, 'minute': 0}, 'close': {'day': 6, 'hour': 23, 'minute': 0}}], 'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u200911:00\u202fPM', 'Tuesday: 7:00\u202fAM\u2009–\u200911:00\u202fPM', 'Wednesday: 7:00\u202fAM\u2009–\u200911:00\u202fPM', 'Thursday: 7:00\u202fAM\u2009–\u200911:00\u202fPM', 'Friday: 7:00\u202fAM\u2009–\u200911:00\u202fPM', 'Saturday: 7:00\u202fAM\u2009–\u200911:00\u202fPM', 'Sunday: 7:00\u202fAM\u2009–\u200911:00\u202fPM']}, 'utcOffsetMinutes': -240, 'adrFormatAddress': '<span class="street-address">29-18 Queens Plaza S</span>, <span class="locality">Queens</span>, <span class="region">NY</span> <span class="postal-code">11101</span>, <span class="country-name">USA</span>', 'businessStatus': 'OPERATIONAL', 'userRatingCount': 315, 'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet', 'iconBackgroundColor': '#4B96F3', 'displayName': {'text': 'City Acres Market', 'languageCode': 'en'}, 'delivery': True, 'currentOpeningHours': {'openNow': True, 'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}, 'close': {'day': 0, 'hour': 23, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 15}}}, {'open': {'day': 1, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}, 'close': {'day': 1, 'hour': 23, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 16}}}, {'open': {'day': 2, 'hour': 7, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}, 'close': {'day': 2, 'hour': 23, 'minute': 0, 'date': {'year': 2023, 'month': 10, 'day': 17}}}, {'open': {'day': 3, 'hour': 7, 'minute': 0, 'date' ...

# %%
import requests
import json

# This method sends the api requet to the Google Places API with my independent key

def locationtextsearchrequest(station: str, lat: float, long: float, radius: float, txtquery: str):
    # should remove key when publishing to github
    myapikey = 'AIzaSyAHpf_Qy97E-SqC5GhEQqYIJrdB11IqkPg'
    url = 'https://places.googleapis.com/v1/places:searchText'
        # 'X-Goog-FieldMask': 'places.displayName,places.rating,places.formattedAddress,places.types,places.viewport'

    headers = {
        'Content-Type': 'application/json',
        'X-Goog-Api-Key': myapikey,
        'X-Goog-FieldMask': '*'

    }
    data = {
        'textQuery': txtquery,
        'maxResultCount': 1,
        'locationBias': {
            'circle': {
                'center': {
                    'latitude': lat,
                    'longitude': long
                },
                'radius': radius   
                }
            }
    }
    # want to create a function that can create a locationbias based on a latitude and longitude created from a search of a location (ex. Upper East Side 72d st)
    # input the long and lat values into the data var here before calling the request

    
    response = requests.post(url, json=data, headers=headers)
    data = json.loads(response.text)
    print(data)
    return data

# %%
# GOals:
 # get the different metrics you can extract out of reviews
# look through each of the reviews at a grocery store (e.g. whole foods, 
# and find out the overall impressions from the customer reveiews"
test
# Out:
# {'places': [{'name': 'places/ChIJXzhOvqtZwokRSOOfSdybUvM',
#    'id': 'ChIJXzhOvqtZwokRSOOfSdybUvM',
#    'types': ['grocery_store',
#     'market',
#     'store',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'nationalPhoneNumber': '(718) 392-2406',
#    'internationalPhoneNumber': '+1 718-392-2406',
#    'formattedAddress': '29-18 Queens Plaza S, Queens, NY 11101, USA',
#    'addressComponents': [{'longText': '29-18',
#      'shortText': '29-18',
#      'types': ['street_number'],
#      'languageCode': 'en-US'},
#     {'longText': 'Queens Plaza South',
#      'shortText': 'Queens Plaza S',
#      'types': ['route'],
#      'languageCode': 'en'},
#     {'longText': 'Long Island City',
#      'shortText': 'LIC',
#      'types': ['neighborhood', 'political'],
#      'languageCode': 'en'},
#     {'longText': 'Queens',
#      'shortText': 'Queens',
#      'types': ['sublocality_level_1', 'sublocality', 'political'],
#      'languageCode': 'en'},
#     {'longText': 'Queens County',
#      'shortText': 'Queens County',
#      'types': ['administrative_area_level_2', 'political'],
#      'languageCode': 'en'},
#     {'longText': 'New York',
#      'shortText': 'NY',
#      'types': ['administrative_area_level_1', 'political'],
#      'languageCode': 'en'},
#     {'longText': 'United States',
#      'shortText': 'US',
#      'types': ['country', 'political'],
#      'languageCode': 'en'},
#     {'longText': '11101',
#      'shortText': '11101',
#      'types': ['postal_code'],
#      'languageCode': 'en-US'}],
#    'plusCode': {'globalCode': '87G8P3X6+JP',
#     'compoundCode': 'P3X6+JP New York, NY, USA'},
#    'location': {'latitude': 40.7490586, 'longitude': -73.9382112},
#    'viewport': {'low': {'latitude': 40.7477967197085,
#      'longitude': -73.9394027802915},
#     'high': {'latitude': 40.750494680291496, 'longitude': -73.9367048197085}},
#    'rating': 4.1,
#    'googleMapsUri': 'https://maps.google.com/?cid=17533247669737087816',
#    'websiteUri': 'http://cityacresmarket.com/',
#    'regularOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0, 'hour': 7, 'minute': 0},
#       'close': {'day': 0, 'hour': 23, 'minute': 0}},
#      {'open': {'day': 1, 'hour': 7, 'minute': 0},
#       'close': {'day': 1, 'hour': 23, 'minute': 0}},
#      {'open': {'day': 2, 'hour': 7, 'minute': 0},
#       'close': {'day': 2, 'hour': 23, 'minute': 0}},
#      {'open': {'day': 3, 'hour': 7, 'minute': 0},
#       'close': {'day': 3, 'hour': 23, 'minute': 0}},
#      {'open': {'day': 4, 'hour': 7, 'minute': 0},
#       'close': {'day': 4, 'hour': 23, 'minute': 0}},
#      {'open': {'day': 5, 'hour': 7, 'minute': 0},
#       'close': {'day': 5, 'hour': 23, 'minute': 0}},
#      {'open': {'day': 6, 'hour': 7, 'minute': 0},
#       'close': {'day': 6, 'hour': 23, 'minute': 0}}],
#     'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Tuesday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Wednesday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Thursday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Friday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Saturday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Sunday: 7:00\u202fAM\u2009–\u200911:00\u202fPM']},
#    'utcOffsetMinutes': -240,
#    'adrFormatAddress': '<span class="street-address">29-18 Queens Plaza S</span>, <span class="locality">Queens</span>, <span class="region">NY</span> <span class="postal-code">11101</span>, <span class="country-name">USA</span>',
#    'businessStatus': 'OPERATIONAL',
#    'userRatingCount': 315,
#    'iconMaskBaseUri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#    'iconBackgroundColor': '#4B96F3',
#    'displayName': {'text': 'City Acres Market', 'languageCode': 'en'},
#    'delivery': True,
#    'currentOpeningHours': {'openNow': True,
#     'periods': [{'open': {'day': 0,
#        'hour': 7,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 15}},
#       'close': {'day': 0,
#        'hour': 23,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 15}}},
#      {'open': {'day': 1,
#        'hour': 7,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 16}},
#       'close': {'day': 1,
#        'hour': 23,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 16}}},
#      {'open': {'day': 2,
#        'hour': 7,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 17}},
#       'close': {'day': 2,
#        'hour': 23,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 17}}},
#      {'open': {'day': 3,
#        'hour': 7,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 18}},
#       'close': {'day': 3,
#        'hour': 23,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 18}}},
#      {'open': {'day': 4,
#        'hour': 7,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 12}},
#       'close': {'day': 4,
#        'hour': 23,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 12}}},
#      {'open': {'day': 5,
#        'hour': 7,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 13}},
#       'close': {'day': 5,
#        'hour': 23,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 13}}},
#      {'open': {'day': 6,
#        'hour': 7,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 14}},
#       'close': {'day': 6,
#        'hour': 23,
#        'minute': 0,
#        'date': {'year': 2023, 'month': 10, 'day': 14}}}],
#     'weekdayDescriptions': ['Monday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Tuesday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Wednesday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Thursday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Friday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Saturday: 7:00\u202fAM\u2009–\u200911:00\u202fPM',
#      'Sunday: 7:00\u202fAM\u2009–\u200911:00\u202fPM']},
#    'reviews': [{'relativePublishTimeDescription': '2 months ago',
#      'rating': 5,
#      'text': {'text': 'While in New York we went to this City Acres Market.  The market is large, but also compact as well. They have a large variety of foods, meats, vegetables,  and personal necessity available.',
#       'languageCode': 'en'},
#      'originalText': {'text': 'While in New York we went to this City Acres Market.  The market is large, but also compact as well. They have a large variety of foods, meats, vegetables,  and personal necessity available.',
#       'languageCode': 'en'},
#      'authorAttribution': {'displayName': 'Diane Evans',
#       'uri': 'https://www.google.com/maps/contrib/102579990958790810091/reviews',
#       'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocLaIO1aQg0fpkeh71YNadUG8o7rQSAxWcHx6mRll2A=s128-c0x00000000-cc-rp-mo-ba5'},
#      'publishTime': '2023-08-12T12:24:59Z'},
#     {'relativePublishTimeDescription': 'in the last week',
#      'rating': 5,
#      'text': {'text': 'High quality selection, but tight in space. Prices are fairly reasonable and the selection is very good. The market is close to Queens Plaza so definitely pop in if you’re in need of something by the subway.',
#       'languageCode': 'en'},
#      'originalText': {'text': 'High quality selection, but tight in space. Prices are fairly reasonable and the selection is very good. The market is close to Queens Plaza so definitely pop in if you’re in need of something by the subway.',
#       'languageCode': 'en'},
#      'authorAttribution': {'displayName': 'Andrew Vilade',
#       'uri': 'https://www.google.com/maps/contrib/109480687736186813091/reviews',
#       'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUFb74_G2E15u5O5XSF4AOiLlIFLn8XXKWf0BQofuFZ4mA=s128-c0x00000000-cc-rp-mo-ba4'},
#      'publishTime': '2023-10-06T13:21:48Z'},
#     {'relativePublishTimeDescription': '7 months ago',
#      'rating': 5,
#      'text': {'text': 'We had City Acres Market cater our event and everything was wonderful!  They made us an antipasto platter and a gorgeous fruit platter and everything was fresh and delicious.  Jordan, the manager, was so helpful.  It was an all around pleasure to work with them.',
#       'languageCode': 'en'},
#      'originalText': {'text': 'We had City Acres Market cater our event and everything was wonderful!  They made us an antipasto platter and a gorgeous fruit platter and everything was fresh and delicious.  Jordan, the manager, was so helpful.  It was an all around pleasure to work with them.',
#       'languageCode': 'en'},
#      'authorAttribution': {'displayName': 'Bryan Cantor',
#       'uri': 'https://www.google.com/maps/contrib/110779639154431170441/reviews',
#       'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjXNoc2Jn1uwCH99zxiYPOIQ33HAMx6CG52sC8TLEc3Mvno=s128-c0x00000000-cc-rp-mo'},
#      'publishTime': '2023-03-16T14:22:34Z'},
#     {'relativePublishTimeDescription': 'a year ago',
#      'rating': 5,
#      'text': {'text': 'Plenty of variety, delicious cheese selection, a wide variety of cooked food choices hot and cold. I had  salmon and cauliflower with a side of chicken soup broth. I went here with some co workers for lunch and was quite pleased.',
#       'languageCode': 'en'},
#      'originalText': {'text': 'Plenty of variety, delicious cheese selection, a wide variety of cooked food choices hot and cold. I had  salmon and cauliflower with a side of chicken soup broth. I went here with some co workers for lunch and was quite pleased.',
#       'languageCode': 'en'},
#      'authorAttribution': {'displayName': 'Mia Speight',
#       'uri': 'https://www.google.com/maps/contrib/114135132640425406269/reviews',
#       'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUR3hMwHhkz-Vl2G1fWhkk0XeIilAUzIjFoqpuro6IM7H_-=s128-c0x00000000-cc-rp-mo-ba6'},
#      'publishTime': '2022-09-05T15:57:18Z'},
#     {'relativePublishTimeDescription': '2 months ago',
#      'rating': 1,
#      'text': {'text': "The only helpful person here was Jordan the manager. I use to love this place ,however it's severely taken a nose dive. They never have whats on the sites sales paper half the time. The majority of the raw meats have gone so down hill, I'd say that only 40 percent of them are edible and fresh. The biggest downfall in quality here is the customer service is abysmal!!! The whole staff needs to be fired and start over. The deli guys are beyond rude, the stock people NEVER want to show where anything is, and the cashiers are more miserable then a visit to the dmv . With the exception of two of them being ok. This use to be my favorite store , sadly it's just meh now. I'm stuck with it as it's the closest to my apartment. Blah 🤮",
#       'languageCode': 'en'},
#      'originalText': {'text': "The only helpful person here was Jordan the manager. I use to love this place ,however it's severely taken a nose dive. They never have whats on the sites sales paper half the time. The majority of the raw meats have gone so down hill, I'd say that only 40 percent of them are edible and fresh. The biggest downfall in quality here is the customer service is abysmal!!! The whole staff needs to be fired and start over. The deli guys are beyond rude, the stock people NEVER want to show where anything is, and the cashiers are more miserable then a visit to the dmv . With the exception of two of them being ok. This use to be my favorite store , sadly it's just meh now. I'm stuck with it as it's the closest to my apartment. Blah 🤮",
#       'languageCode': 'en'},
#      'authorAttribution': {'displayName': 'Eliana',
#       'uri': 'https://www.google.com/maps/contrib/102302006827471184571/reviews',
#       'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjXuJjROeRmLse0yMLYYVQ6T5PrpFI7LJbGAxCBF922GVmg=s128-c0x00000000-cc-rp-mo-ba3'},
#      'publishTime': '2023-08-12T22:35:14Z'}],
#    'accessibilityOptions': {'wheelchairAccessibleEntrance': True}}]}

# %%
import json
# sort through the big json and pull out the info we need
# want an array of all the reviews, so then can use a NLP at later step to analyze arguments and determine sentiment
# want the avg rating and avg price point
# pull name, and location in city


# test

def sortjson(jsonfile):
    
    # probably should have try statements for each of these fields incase of error
    myfile = jsonfile['places'][0]
    name = myfile['displayName']['text']
    websiteurl = myfile['websiteUri']
    # currently pulls 5 reviews, need to modify it to get more reviews or reviews sorted by some param
    reviewslist = myfile['reviews']
    pricelevel = 'N/A'
    try: 
        pricelevel = myfile['priceLevel']
    except:
        pass
    # print(reviewslist)
    ret=[name, websiteurl, pricelevel, reviewslist]
    return ret

mysortedjson = sortjson(test)
mysortedjson
# Out:
# ['City Acres Market',
#  'http://cityacresmarket.com/',
#  'N/A',
#  [{'relativePublishTimeDescription': '2 months ago',
#    'rating': 5,
#    'text': {'text': 'While in New York we went to this City Acres Market.  The market is large, but also compact as well. They have a large variety of foods, meats, vegetables,  and personal necessity available.',
#     'languageCode': 'en'},
#    'originalText': {'text': 'While in New York we went to this City Acres Market.  The market is large, but also compact as well. They have a large variety of foods, meats, vegetables,  and personal necessity available.',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Diane Evans',
#     'uri': 'https://www.google.com/maps/contrib/102579990958790810091/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a/ACg8ocLaIO1aQg0fpkeh71YNadUG8o7rQSAxWcHx6mRll2A=s128-c0x00000000-cc-rp-mo-ba5'},
#    'publishTime': '2023-08-12T12:24:59Z'},
#   {'relativePublishTimeDescription': 'in the last week',
#    'rating': 5,
#    'text': {'text': 'High quality selection, but tight in space. Prices are fairly reasonable and the selection is very good. The market is close to Queens Plaza so definitely pop in if you’re in need of something by the subway.',
#     'languageCode': 'en'},
#    'originalText': {'text': 'High quality selection, but tight in space. Prices are fairly reasonable and the selection is very good. The market is close to Queens Plaza so definitely pop in if you’re in need of something by the subway.',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Andrew Vilade',
#     'uri': 'https://www.google.com/maps/contrib/109480687736186813091/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUFb74_G2E15u5O5XSF4AOiLlIFLn8XXKWf0BQofuFZ4mA=s128-c0x00000000-cc-rp-mo-ba4'},
#    'publishTime': '2023-10-06T13:21:48Z'},
#   {'relativePublishTimeDescription': '7 months ago',
#    'rating': 5,
#    'text': {'text': 'We had City Acres Market cater our event and everything was wonderful!  They made us an antipasto platter and a gorgeous fruit platter and everything was fresh and delicious.  Jordan, the manager, was so helpful.  It was an all around pleasure to work with them.',
#     'languageCode': 'en'},
#    'originalText': {'text': 'We had City Acres Market cater our event and everything was wonderful!  They made us an antipasto platter and a gorgeous fruit platter and everything was fresh and delicious.  Jordan, the manager, was so helpful.  It was an all around pleasure to work with them.',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Bryan Cantor',
#     'uri': 'https://www.google.com/maps/contrib/110779639154431170441/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjXNoc2Jn1uwCH99zxiYPOIQ33HAMx6CG52sC8TLEc3Mvno=s128-c0x00000000-cc-rp-mo'},
#    'publishTime': '2023-03-16T14:22:34Z'},
#   {'relativePublishTimeDescription': 'a year ago',
#    'rating': 5,
#    'text': {'text': 'Plenty of variety, delicious cheese selection, a wide variety of cooked food choices hot and cold. I had  salmon and cauliflower with a side of chicken soup broth. I went here with some co workers for lunch and was quite pleased.',
#     'languageCode': 'en'},
#    'originalText': {'text': 'Plenty of variety, delicious cheese selection, a wide variety of cooked food choices hot and cold. I had  salmon and cauliflower with a side of chicken soup broth. I went here with some co workers for lunch and was quite pleased.',
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Mia Speight',
#     'uri': 'https://www.google.com/maps/contrib/114135132640425406269/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjUR3hMwHhkz-Vl2G1fWhkk0XeIilAUzIjFoqpuro6IM7H_-=s128-c0x00000000-cc-rp-mo-ba6'},
#    'publishTime': '2022-09-05T15:57:18Z'},
#   {'relativePublishTimeDescription': '2 months ago',
#    'rating': 1,
#    'text': {'text': "The only helpful person here was Jordan the manager. I use to love this place ,however it's severely taken a nose dive. They never have whats on the sites sales paper half the time. The majority of the raw meats have gone so down hill, I'd say that only 40 percent of them are edible and fresh. The biggest downfall in quality here is the customer service is abysmal!!! The whole staff needs to be fired and start over. The deli guys are beyond rude, the stock people NEVER want to show where anything is, and the cashiers are more miserable then a visit to the dmv . With the exception of two of them being ok. This use to be my favorite store , sadly it's just meh now. I'm stuck with it as it's the closest to my apartment. Blah 🤮",
#     'languageCode': 'en'},
#    'originalText': {'text': "The only helpful person here was Jordan the manager. I use to love this place ,however it's severely taken a nose dive. They never have whats on the sites sales paper half the time. The majority of the raw meats have gone so down hill, I'd say that only 40 percent of them are edible and fresh. The biggest downfall in quality here is the customer service is abysmal!!! The whole staff needs to be fired and start over. The deli guys are beyond rude, the stock people NEVER want to show where anything is, and the cashiers are more miserable then a visit to the dmv . With the exception of two of them being ok. This use to be my favorite store , sadly it's just meh now. I'm stuck with it as it's the closest to my apartment. Blah 🤮",
#     'languageCode': 'en'},
#    'authorAttribution': {'displayName': 'Eliana',
#     'uri': 'https://www.google.com/maps/contrib/102302006827471184571/reviews',
#     'photoUri': 'https://lh3.googleusercontent.com/a-/ALV-UjXuJjROeRmLse0yMLYYVQ6T5PrpFI7LJbGAxCBF922GVmg=s128-c0x00000000-cc-rp-mo-ba3'},
#    'publishTime': '2023-08-12T22:35:14Z'}]]

# %%
# Descripton of Roots:
# A ethnic indian chai flavored protein powder with organic ingredients targeted for weightlifters interested in diverse flavors 
# and cultural heritage
# * add desc of where we want to sell roots, target markets and size 
# see if nlp model can compare this claim to the ai models


input = "A food market with quality food products of diverse ethnic backgrounds "
# Hugging faces inferences api 
# https://huggingface.co/ProsusAI/finbert?text=Stocks+rallied+and+the+British+pound+gained.
# FinBERT is a pre-trained NLP model to analyze sentiment of financial text

# Summarize  like 10 reviews together if possible with one of the api's then for a series of locations summaries run the below query 
# find out which regions have the highest scores compared to the source sentence

import requests

API_URL = "https://api-inference.huggingface.co/models/sentence-transformers/all-MiniLM-L6-v2"
headers = {"Authorization": "Bearer "}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": {
		"source_sentence": "That is a happy person",
		"sentences": [
			"That is a happy dog",
			"That is a very happy person",
			"Today is a sunny day"
		]
	},
})

output
# Out:
# [0.6945773363113403, 0.9429150223731995, 0.256876140832901]
